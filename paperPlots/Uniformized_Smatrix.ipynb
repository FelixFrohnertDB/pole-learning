# %% [markdown]
# ### Coupled two-channel analysis: Background and poles
#
# We consider the two-channel S-matrix satisfying unitarity, hermiticity and analyticity. <br>
#
# <br>
# \begin{equation}
# S_{11}=\dfrac{D(-p_1,p_2)}{D(p_1,p_2)};\quad
# S_{22}=\dfrac{D(p_1,-p_2)}{D(p_1,p_2)};\quad\mbox{and}\quad
# \mbox{det }S = \dfrac{D(-p_1,-p_2)}{D(p_1,p_2)}
# \end{equation}
# <br>
# where $D(p_1,p_2)$ will determine the pole position and the Riemann sheet. Background will also be incorporated inside $D(p_1,p_2)$. <br>
#
# The channel momentum $p_n$ is given by the relativistic expression:
# <br>
# \begin{equation}
# p_n=\sqrt{\dfrac{(s-(m_{n1}+m_{n2})^2)(s-(m_{n1}-m_{n2})^2)}{4s}}.
# \end{equation}
# <br>
# We are only interested in the region near the threshold. It will suffice to utilize the simplified momentum:
# \begin{equation}
# q_n^2=s-(m_{n1}+m_{n2})^2.
# \end{equation}
# <br>
#
# Initialize:

# %%
import math
import numpy as np
import cmath as cm
import random
import pickle
import os
import pandas as pd
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

####################################
#Units in MeV
# constants
hbarc = 197.3
# Heavy quark sector
# Units in MeV
JPsi = 3096.90
Proton = 938.27208816
Dplus = 1869.66
Dbar0 = 1864.83
Sigmaplus = 1189.37
Sigmaplus_C = 2452.9

# Define thresholds
T1 = (JPsi + Proton)/hbarc
T2 = (Sigmaplus_C + Dbar0)/hbarc
T4 = 4350/hbarc

NEpoints = 1500
#Generate energy axis 
Einput = []
delE = (T2 - T1 + 500/197.3)*197.3/(NEpoints)
for ndx in range(NEpoints):
    Einput.append(np.random.uniform(low=T1*197.3+(ndx)*delE, high=T1*197.3+(ndx+1)*delE))
Einput = np.array(Einput)             
#vectorize function evaluation
q1 = np.sqrt(Einput**2.0-(T1*197.3)**2.0)
q2 = []
#cmath can't take array input.
for kndx in range(len(Einput)):
    q2.append(cm.sqrt(Einput[kndx]**2.0-(T1*197.3)**2.0))
q2 = np.asarray(q2)

# %% [markdown]
# We use the uniformized parametrization to generate the poles. <br>
# Introduce uniformized parameter: $\omega=\dfrac{p_1+p_2}{\sqrt{\epsilon_2^2-\epsilon_1^2}}$ (linear form eliminates the production of extra pole) <br>
# Background can be represented by distant uniformized poles; $Re E_{pole}<<T_1$ .

# %%
#Class that takes the input Riemann sheet and pole position.
#The regulator pole is automatically calculated.
#The S-matrix contribution of the input pole is obtained by the calling the method .smat11 and .smat22

class unif_pole:
    def __init__(self, RS, Ereal, Eimag):
        #RS is the two-channel Reimann sheet location of the pole
        #Use [-1,1] for bt, [-1,-1] for bb and [1,-1] for tb
        
        #Ereal is the real part of energy pole
        #Eimag is the imag part of energy pole
        Epole = Ereal - (1j)*Eimag
        self.pos = Epole
        #compute uniformized momentum pole
        #for channel 1 and channel 2
        k1pole = cm.sqrt((Epole/197.3)**2-T1**2)
        k2pole = cm.sqrt((Epole/197.3)**2-T2**2)
        #Assign Riemann sheet
        beta1  = RS[0]*abs(k1pole.imag)
        beta2  = RS[1]*abs(k2pole.imag)
        #Get the real part, we need to be consistent with signs
        alpha1 = -np.sign(beta1)*np.abs(k1pole.real)
        alpha2 = -np.sign(beta2)*np.abs(k2pole.real)

        #Just for counterchecking
        #signs of beta1 and beta2 should agree 
        #with RS[0] and RS[1], respectively
        self.alpha1 = alpha1
        self.alpha2 = alpha2
        self.beta1 = beta1
        self.beta2 = beta2
        
        #Construct pole channel momenta
        polep1 = (1j)*beta1 + alpha1
        polep2 = (1j)*beta2 + alpha2
        
        Delta = cm.sqrt(T2**2 - T1**2)
        self.Delta = Delta
        
        #Perfrom uniformization of the assigned pole
        omega_pole = (polep1 + polep2)/Delta
        recip_omg_pol = 1/omega_pole
        self.omega_pole = omega_pole
        self.recip_omg_pol = recip_omg_pol
        
        #Get pole regulator
        #[bt] sheet
        if RS==[-1,1]: 
            omega_reg = np.abs(recip_omg_pol)*cm.exp(-0.5*np.pi*(1j))
        #[bb] sheet
        elif RS==[-1,-1]:
            omega_reg = np.abs(recip_omg_pol)*cm.exp(-0.5*np.pi*(1j))
        #[tb] sheet
        elif RS==[1,-1]:
            omega_reg = np.abs(recip_omg_pol)*cm.exp(-0.5*np.pi*(1j))
            
        self.omega_reg = omega_reg
        self.recip_omg_reg = 1/omega_reg
        
        p1_reg = omega_reg + 1/omega_reg
        p2_reg = omega_reg - 1/omega_reg
        
        #Riemann sheet identifier for pole regulator
        def RSlabel(pimag1, pimag2):
            if pimag1>0 and pimag2>0:
                RS = 'tt'
            elif pimag1<0 and pimag2>0:
                RS = 'bt'
            elif pimag1<0 and pimag2<0:
                RS = 'bb'
            elif pimag1>0 and pimag2<0:
                RS = 'tb'
            return RS
        #If you want to check the Riemann sheet of pole regulator
        self.regulator = ['{:.2f}'.format(np.sqrt(p1_reg**2.0+T1**2.0)*197.3), RSlabel(p1_reg.imag, p2_reg.imag)]
        self.assignedpole = ['{:.2f}'.format(np.sqrt(polep1**2.0+T1**2.0)*197.3), RSlabel(polep1.imag, polep2.imag)]
        self.input = ['{:.2f}'.format(Epole), RSlabel(polep1.imag, polep2.imag)]
    
    #The indent on this part is very important
    #Claculate the S-matrix contribution of the uniformized pole
    def smat11(self, Ecm):
        #Get channel momenta of Ecm
        #vectorize function evaluation
        p1 = np.sqrt((Ecm/197.3)**2.0-T1**2.0)
        #cmath cannot take array input
        #we use the almighty for loop to vectorize p2
        p2 = []
        for pndx in range(len(Ecm)):
            p2.append(cm.sqrt((Ecm[pndx]/197.3)**2.0-T2**2.0))
        p2 = np.asarray(p2)

        #Get uniformized parameter
        omega = (p1 + p2)/self.Delta
        #Numerator of S-matrix
        Numpol = (omega-np.conj(self.recip_omg_pol))*(omega+self.recip_omg_pol)
        Numreg = (omega-np.conj(self.recip_omg_reg))*(omega+self.recip_omg_reg)
        Num = Numpol*Numreg
        #Denominator of S-matrix
        Denpol = (omega-self.omega_pole)*(omega+np.conj(self.omega_pole))
        Denreg = (omega-self.omega_reg)*(omega+np.conj(self.omega_reg))
        Den = Denpol*Denreg
            
        return np.abs(1/(self.omega_pole*self.omega_reg))**2.0*Num/Den
    
    def smat22(self, Ecm):
        #Get channel momenta of Ecm
        #vectorize function evaluation
        p1 = np.sqrt((Ecm/197.3)**2.0-T1**2.0)
        #cmath cannot take array input
        #we use the almighty for loop to vectorize p2
        p2 = []
        for pndx in range(len(Ecm)):
            p2.append(cm.sqrt((Ecm[pndx]/197.3)**2.0-T2**2.0))
        p2 = np.asarray(p2)

        #Get uniformized parameter
        omega = (p1 + p2)/self.Delta
        #Numerator of S-matrix
        Numpol = (omega+np.conj(self.recip_omg_pol))*(omega-self.recip_omg_pol)
        Numreg = (omega+np.conj(self.recip_omg_reg))*(omega-self.recip_omg_reg)
        Num = Numpol*Numreg
        #Denominator of S-matrix
        Denpol = (omega-self.omega_pole)*(omega+np.conj(self.omega_pole))
        Denreg = (omega-self.omega_reg)*(omega+np.conj(self.omega_reg))
        Den = Denpol*Denreg
            
        return np.abs((self.omega_pole*self.omega_reg))**2.0*Num/Den

# %% [markdown]
# In the following codes, we will create an object called pole and plot the corresponding elastic cross-sections.<br>
# Note that the Riemann sheets should take:<br>
# Sheet 2 (bt): [-1,1] <br>
# Sheet 3 (bb): [-1,-1] <br>
# Sheet 4 (tb): [1,-1] <br>

# %%
font_set_size = 30
font_set_size2 = 20
font_set_size3 = 25
line_thickness = 4

# %%
plt.figure(figsize=(6,6))

# Define the size of the complex plane
plane_size = 2.0  # Adjust this value to change the size of the complex plane

# Generate a grid of complex numbers in the desired range
x = np.linspace(-plane_size, plane_size, 500)
y = np.linspace(-plane_size, plane_size, 500)
X, Y = np.meshgrid(x, y)
Z = X + 1j * Y

# Compute the quadrant indices
quadrant = np.zeros_like(Z, dtype=int)
quadrant = np.where(Z.imag >= 0, 1, 3)  # Upper half plane: 1, Lower half plane: 3

# Determine the points inside the unit circle
inside_circle = np.abs(Z) < 1

# Assign colors based on the upper/lower half plane and inside/outside the unit circle
quadrant = np.where(inside_circle, quadrant + 1, quadrant)  # Inside circle: 2, Outside circle: 1 or 3

# Define your own colors for the quadrants
colors = ['aliceblue', 'lightgreen', 'mistyrose', 'thistle']

# Create a custom color map
cmap = mcolors.ListedColormap(colors)

# Plot the complex plane with color-coded quadrants
plt.scatter(Z.real, Z.imag, c=quadrant, cmap=cmap)

# Add lines along the imaginary and real axes
plt.axhline(0, color='gray', linestyle='dashed')
plt.axvline(0, color='gray', linestyle='dashed')

# Determine the maximum radius required to fill the frame
#max_radius = np.max(np.abs(np.concatenate([x, y])))

# Add concentric circular grid lines
radii = np.arange(0.2, 2.0*plane_size + 0.2, 0.2)
for r in radii:
    circle = plt.Circle((0, 0), r, color='gray', linestyle='dashed', fill=False)
    plt.gca().add_patch(circle)

# Add radial grid lines
angles = np.arange(0, 360, 30)
for angle in angles:
    theta = np.radians(angle)
    x = np.cos(theta)
    y = np.sin(theta)
    plt.plot([0, 2.0*plane_size*x], [0, 2.0*plane_size*y], color='gray', linestyle='dashed')

# Add solid lines
#plt.plot([0, 0], [1, plane_size], color='black', linewidth=2)  # Vertical line from +2i to +1i
theta = np.linspace(0, np.pi/2, 100)
circle = np.exp(1j * theta)
plt.plot(circle.real, circle.imag, color='red', linewidth=5)  # Quarter unit circle from +1i to +1
plt.plot([1, plane_size], [0, 0], color='maroon', linewidth=5)  # Horizontal line from +1 to +2

# Add text boxes with labels in each quadrant outside the unit circle
# Add text boxes with transparent background and no borders
RSfonts = 25
plt.text(1.7, 1.7, r'$\omega$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='black'))
plt.text(0.9, 1.0, r'$[tt]_{+}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
plt.text(-1.5, 1.0, r'$[tt]_{-}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
plt.text(0.9, -1.2, r'$[bb]_{-}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
plt.text(-1.5, -1.2, r'$[bb]_{+}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
plt.text(0.2, 0.2, r'$[bt]_{-}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
plt.text(-0.9, 0.2, r'$[bt]_{+}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
plt.text(0.2, -0.5, r'$[tb]_{+}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
plt.text(-0.9, -0.5, r'$[tb]_{-}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
# Set aspect ratio to 'equal' for a circular unit circle
plt.gca().set_aspect('equal', adjustable='box')

# Remove color bar
plt.colorbar().remove()

# Add labels and title
#plt.xlabel('Re ω', fontsize=font_set_size2, ha='center', va='center', transform=plt.gcf().transFigure)
#plt.ylabel('Im ω', fontsize=font_set_size2, ha='center', va='center', transform=plt.gcf().transFigure)
plt.xticks([-2, -1, 1, 2], fontsize=font_set_size2)
plt.yticks([-2, -1, 1, 2], fontsize=font_set_size2)
# Adjust the position of the x-axis and y-axis labels
#plt.gca().xaxis.set_label_coords(0.9, 0.45)
#plt.gca().yaxis.set_label_coords(0.55, 0.90)

# Set plot limits to remove extra spaces
plt.xlim(-plane_size, plane_size)
plt.ylim(-plane_size, plane_size)

# Add points with custom marker size
point_size = 200  # Adjust this value to change the marker size

ϵ1 = (1j)
ϵ2 = (1)
plt.scatter(ϵ1.real, ϵ1.imag, color='red', marker='o', s=point_size)
plt.scatter(ϵ2.real, ϵ2.imag, color='maroon', marker='o', s=point_size)

# ωpole=pole1.omega_pole
# ωpoleconjg=-np.conj(pole1.omega_pole)
# plt.scatter(ωpole.real, ωpole.imag, color='blue', marker='o', s=point_size)
# plt.scatter(ωpoleconjg.real, ωpoleconjg.imag, color='blue', marker='o', s=point_size)

# ωreg=pole1.omega_reg
# ωregconjg=-np.conj(pole1.omega_reg)
# plt.scatter(ωreg.real, ωreg.imag, color='blue', marker='*', s=point_size)
# plt.scatter(ωregconjg.real, ωregconjg.imag, color='blue', marker='*', s=point_size)
# Display the plot
plt.savefig("omegaplane.pdf")
plt.show()

# %% [markdown]
# ### One-pole structure

# %%
pole1 = unif_pole([-1,1],T2*197.3-10.0,50)

# %%
import matplotlib.pyplot as plt
from utils import utils_ml

# Compute scattering amplitude
onepole_S11 = pole1.smat11(Einput)
onepole_T11 = (onepole_S11 - 1.0) / (2.0 * 1j)

# Energy range to display
strt = 1
end = NEpoints

# Constants for labeling
threshold_energy = T2 * 197.3

# Plot settings
fig, ax = plt.subplots(figsize=(3.4, 2.8))  # Single-column size
ax.set_ylim(-0.55, 1.1)

# Plot components of the amplitude
ax.plot(Einput[strt:end], abs(onepole_T11[strt:end])**2, 'g--', lw=1.5, label=r'$|T_{11}(E)|^2$')
ax.plot(Einput[strt:end], onepole_T11[strt:end].real, 'r-', lw=1.5, label=r'$\mathrm{Re}\,T_{11}(E)$')
ax.plot(Einput[strt:end], onepole_T11[strt:end].imag, 'b-', lw=1.5, label=r'$\mathrm{Im}\,T_{11}(E)$')

# Threshold line
ax.axvline(x=threshold_energy, color='k', linestyle='--', lw=1.8, label=r'$\Sigma_c^+ \overline{D}^0$')

# Axis and ticks
ax.set_xlabel(r'$\sqrt{s}_{J/\psi p}$ [MeV]', fontsize=10)
ax.set_ylabel(r'Amplitude ', fontsize=10)
ax.set_xticks([T1 * 197.3, T2 * 197.3, T2 * 197.3 + 450.0])
ax.tick_params(labelsize=9)

# Legend
ax.legend(loc='upper right', fontsize=9, frameon=True)

# Grid and layout
ax.grid(True, linestyle=':', linewidth=0.5)
plt.tight_layout()

# Save
plt.savefig("btlineshape.pdf", dpi=300)
plt.show()

# %% [markdown]
# ### Three-pole structure: ambigous case

# %%
#Add extra poles in the 3rd and 4th Riemann sheets
pole2 = unif_pole([-1,-1],T2*197.3-10.0,50)
pole3 = unif_pole([1,-1],T2*197.3-10.0,50)

# %%
# #This is for the three pole case
# onepole_S11 = pole1.smat11(Einput)*pole2.smat11(Einput)*pole3.smat11(Einput)
# #Calculate the amplitude (let me call that pole1_T11)
# onepole_T11 = (onepole_S11 - 1.0)/(2.0*(1j))
# #Now, let us plot the elastic cross-section:
# #Some parts of the following codes are just for aesthetic
# strt = 1
# end = NEpoints

# fig = plt.figure(figsize=(10,8)) #empty figure with nothing
# max_y = 1.1
# plt.ylim(-0.55,max_y)

# #This is the plot part
# #Note that we are plotting the |pole1_T11|^2 vs the Einput (center of mass energy)
# plt.plot(Einput[strt:end],abs(onepole_T11[strt:end])**2.0,'g--', linewidth=line_thickness, label=r'$|T_{11}(E)|^2$')
# plt.plot(Einput[strt:end],onepole_T11[strt:end].real,'r-', linewidth=line_thickness, label=r'$ReT_{11}(E)$')
# plt.plot(Einput[strt:end],onepole_T11[strt:end].imag,'b-', linewidth=line_thickness, label=r'$ImT_{11}(E)$')
# plt.axvline(x=T2*197.3, color='k', linestyle='--', linewidth=3, label=r'$\Sigma_c^{+}\overline{D}^0$')

# legend = plt.legend(loc='upper right', shadow=True, fontsize=font_set_size2)

# plt.yticks(fontsize=font_set_size)
# plt.xticks([T1*197.3, T2*197.3, T2*197.3+450.0], fontsize=font_set_size)
# plt.xlabel(r'$\sqrt{s}_{J/\psi p}$', fontsize = font_set_size)
# plt.grid(True)
# plt.savefig("btlineshape.pdf")
# plt.show()

# %%
plt.figure(figsize=(6,6))

# Define the size of the complex plane
plane_size = 2.0  # Adjust this value to change the size of the complex plane

# Generate a grid of complex numbers in the desired range
x = np.linspace(-plane_size, plane_size, 500)
y = np.linspace(-plane_size, plane_size, 500)
X, Y = np.meshgrid(x, y)
Z = X + 1j * Y

# Compute the quadrant indices
quadrant = np.zeros_like(Z, dtype=int)
quadrant = np.where(Z.imag >= 0, 1, 3)  # Upper half plane: 1, Lower half plane: 3

# Determine the points inside the unit circle
inside_circle = np.abs(Z) < 1

# Assign colors based on the upper/lower half plane and inside/outside the unit circle
quadrant = np.where(inside_circle, quadrant + 1, quadrant)  # Inside circle: 2, Outside circle: 1 or 3

# Define your own colors for the quadrants
colors = ['aliceblue', 'lightgreen', 'mistyrose', 'thistle']

# Create a custom color map
cmap = mcolors.ListedColormap(colors)

# Plot the complex plane with color-coded quadrants
plt.scatter(Z.real, Z.imag, c=quadrant, cmap=cmap)

# Add lines along the imaginary and real axes
plt.axhline(0, color='gray', linestyle='dashed')
plt.axvline(0, color='gray', linestyle='dashed')

# Determine the maximum radius required to fill the frame
#max_radius = np.max(np.abs(np.concatenate([x, y])))

# Add concentric circular grid lines
radii = np.arange(0.2, 2.0*plane_size + 0.2, 0.2)
for r in radii:
    circle = plt.Circle((0, 0), r, color='gray', linestyle='dashed', fill=False)
    plt.gca().add_patch(circle)

# Add radial grid lines
angles = np.arange(0, 360, 30)
for angle in angles:
    theta = np.radians(angle)
    x = np.cos(theta)
    y = np.sin(theta)
    plt.plot([0, 2.0*plane_size*x], [0, 2.0*plane_size*y], color='gray', linestyle='dashed')

# Add solid lines
#plt.plot([0, 0], [1, plane_size], color='black', linewidth=2)  # Vertical line from +2i to +1i
theta = np.linspace(0, np.pi/2, 100)
circle = np.exp(1j * theta)
plt.plot(circle.real, circle.imag, color='red', linewidth=5)  # Quarter unit circle from +1i to +1
plt.plot([1, plane_size], [0, 0], color='maroon', linewidth=5)  # Horizontal line from +1 to +2

# Add text boxes with labels in each quadrant outside the unit circle
# Add text boxes with transparent background and no borders
RSfonts = 25
plt.text(1.7, 1.7, r'$\omega$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='black'))
# plt.text(0.9, 1.0, r'$[tt]_{+}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
# plt.text(-1.5, 1.0, r'$[tt]_{-}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
# plt.text(0.9, -1.2, r'$[bb]_{-}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
# plt.text(-1.5, -1.2, r'$[bb]_{+}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
# plt.text(0.2, 0.2, r'$[bt]_{-}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
# plt.text(-0.9, 0.2, r'$[bt]_{+}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
# plt.text(0.2, -0.5, r'$[tb]_{+}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))
# plt.text(-0.9, -0.5, r'$[tb]_{-}$', fontsize=RSfonts, color='black', bbox=dict(facecolor='none', edgecolor='none'))

# Set aspect ratio to 'equal' for a circular unit circle
plt.gca().set_aspect('equal', adjustable='box')

# Remove color bar
plt.colorbar().remove()

# Add labels and title
#plt.xlabel('Re ω', fontsize=font_set_size2, ha='center', va='center', transform=plt.gcf().transFigure)
#plt.ylabel('Im ω', fontsize=font_set_size2, ha='center', va='center', transform=plt.gcf().transFigure)
plt.xticks([-2, -1, 1, 2], fontsize=font_set_size2)
plt.yticks([-2, -1, 1, 2], fontsize=font_set_size2)
# Adjust the position of the x-axis and y-axis labels
#plt.gca().xaxis.set_label_coords(0.9, 0.45)
#plt.gca().yaxis.set_label_coords(0.55, 0.90)

# Set plot limits to remove extra spaces
plt.xlim(-plane_size, plane_size)
plt.ylim(-plane_size, plane_size)

# Add points with custom marker size
point_size = 200  # Adjust this value to change the marker size

ϵ1 = (1j)
ϵ2 = (1)
plt.scatter(ϵ1.real, ϵ1.imag, color='red', marker='o', s=point_size)
plt.scatter(ϵ2.real, ϵ2.imag, color='maroon', marker='o', s=point_size)

ωpole1=pole1.omega_pole
ωpole1conjg=-np.conj(pole1.omega_pole)
plt.scatter(ωpole1.real, ωpole1.imag, color='blue', marker='o', s=point_size)
plt.scatter(ωpole1conjg.real, ωpole1conjg.imag, color='blue', marker='o', s=point_size)
ωreg1=pole1.omega_reg
ωreg1conjg=-np.conj(pole1.omega_reg)
plt.scatter(ωreg1.real, ωreg1.imag, color='blue', marker='*', s=point_size)
plt.scatter(ωreg1conjg.real, ωreg1conjg.imag, color='blue', marker='*', s=point_size)

ωpole2=pole2.omega_pole
ωpole2conjg=-np.conj(pole2.omega_pole)
plt.scatter(ωpole2.real, ωpole2.imag, color='green', marker='o', s=point_size)
plt.scatter(ωpole2conjg.real, ωpole2conjg.imag, color='green', marker='o', s=point_size)
ωreg2=pole2.omega_reg
ωreg2conjg=-np.conj(pole2.omega_reg)
plt.scatter(ωreg2.real, ωreg2.imag, color='green', marker='*', s=point_size)
plt.scatter(ωreg2conjg.real, ωreg2conjg.imag, color='green', marker='*', s=point_size)

ωpole3=pole3.omega_pole
ωpole3conjg=-np.conj(pole3.omega_pole)
plt.scatter(ωpole3.real, ωpole3.imag, color='red', marker='o', s=point_size)
plt.scatter(ωpole3conjg.real, ωpole3conjg.imag, color='red', marker='o', s=point_size)
ωreg3=pole3.omega_reg
ωreg3conjg=-np.conj(pole3.omega_reg)
plt.scatter(ωreg3.real, ωreg3.imag, color='red', marker='*', s=point_size)
plt.scatter(ωreg3conjg.real, ωreg3conjg.imag, color='red', marker='*', s=point_size)
# Display the plot
plt.savefig("ambigous.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from utils import utils_ml

# Create the combined figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6.15, 2.75))

# ===== LEFT SUBPLOT: Circle plot =====
# Set the limits
ax1.set_xlim(-2, 2)
ax1.set_ylim(-2, 2)

# Create meshgrid
x = np.linspace(-3, 3, 500)
y = np.linspace(-3, 3, 500)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Theta = np.arctan2(Y, X)

# Define colors
colors = {
    "top_inner": "#A16D47",      # Muted clay (warm, earthy orange-brown)  
    "bottom_inner": "#776F4F",   # Toasted almond (subtle tan/golden beige)
    "top_outer": "#C0AD8D",      # Sage green (natural, calming)
    "bottom_outer": "#D8CABA"    # Olive green (deep, grounding)
}

# Define regions by angle and radius with appropriate colors
regions = [
    ((R <= 1) & (Y >= 0), colors["top_inner"]),      # top inner
    ((R <= 1) & (Y < 0), colors["bottom_inner"]),     # bottom inner
    ((R > 1) & (R <= 3) & (Y >= 0), colors["top_outer"]),  # top outer
    ((R > 1) & (R <= 3) & (Y < 0), colors["bottom_outer"])       # bottom outer
]

# Plot each region
for mask, color in regions:
    ax1.contourf(X, Y, mask, levels=[0.5, 1], colors=[color])

# Draw radial grid lines (black)
for angle in np.linspace(0, 2 * np.pi, 12, endpoint=False):
    ax1.plot([0, 3 * np.cos(angle)], [0, 3 * np.sin(angle)], color='black', lw=0.5)

# Draw concentric circles (black)
for r in np.linspace(0.5, 3, 6):
    circle = plt.Circle((0, 0), r, color='black', fill=False, lw=0.5)
    ax1.add_artist(circle)

# Draw x and y axes
ax1.axhline(0, color='black', lw=1)
ax1.axvline(0, color='black', lw=1)

# Set integer ticks
ticks = [-2, -1, 0, 1, 2]
ax1.set_xticks(ticks)
ax1.set_yticks(ticks)
ax1.tick_params(labelsize=9)

# Set equal aspect ratio
ax1.set_aspect('equal')

# Add axis labels for consistency
# ax1.set_xlabel('X', fontsize=10)
# ax1.set_ylabel('Y', fontsize=10)

# ===== RIGHT SUBPLOT: Line plot =====
# Compute scattering amplitude (assuming you have the data)
onepole_S11 = pole1.smat11(Einput)
onepole_T11 = (onepole_S11 - 1.0) / (2.0 * 1j)

# Energy range to display
strt = 1
end = NEpoints

# Constants for labeling
threshold_energy = T2 * 197.3

# Plot settings
ax2.set_ylim(-0.55, 1.1)

# Plot components of the amplitude
ax2.plot(Einput[strt:end], abs(onepole_T11[strt:end])**2, '#F6C63F', lw=1.5, label=r'$|T_{11}(E)|^2$')
ax2.plot(Einput[strt:end], onepole_T11[strt:end].real, '#D99873', lw=1.5, label=r'$\mathrm{Re}\,T_{11}(E)$')
ax2.plot(Einput[strt:end], onepole_T11[strt:end].imag, '#A5BFD2', lw=1.5, label=r'$\mathrm{Im}\,T_{11}(E)$')
ax2.axvline(x=threshold_energy, color='k', linestyle='--', lw=1.8, label=r'$\Sigma_c^+ \overline{D}^0$')

	


# Axis and ticks
ax2.set_xlabel(r'$\sqrt{s}_{J/\psi p}$ [MeV]', fontsize=10)
ax2.set_ylabel(r'Amplitude ', fontsize=10)
ax2.set_xticks([T1 * 197.3, T2 * 197.3, T2 * 197.3 + 450.0])
ax2.tick_params(labelsize=9)

# Legend
ax2.legend(loc='upper right', fontsize=9, frameon=True)

# Grid
ax2.grid(True, linestyle=':', linewidth=0.5)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.3)

# Save and show
plt.tight_layout()
plt.savefig("combined_figure.png", dpi=800, transparent=True, bbox_inches='tight', pad_inches=0.1)
plt.show()
