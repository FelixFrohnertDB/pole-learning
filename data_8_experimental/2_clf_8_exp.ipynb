# %%
from codebase.utils_ml import *

# %%
features_memmap = np.load('features_filtered.npy', mmap_mode='r')
label_arr = np.array([np.tile(i,3000) for i in np.arange(0,8)]).flatten()

# %%
clf = CatBoostClassifier(
        verbose=100,  
        random_state=42         
        )
    
clf.fit(features_memmap, label_arr, plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Learning rate set to 0.093049
# 0:	learn: 1.7870769	total: 465ms	remaining: 7m 44s
# 100:	learn: 0.3417387	total: 38.7s	remaining: 5m 44s
# 200:	learn: 0.2464442	total: 1m 15s	remaining: 5m
# 300:	learn: 0.2028604	total: 1m 51s	remaining: 4m 19s
# 400:	learn: 0.1748017	total: 2m 28s	remaining: 3m 41s
# 500:	learn: 0.1553474	total: 3m 3s	remaining: 3m 3s
# 600:	learn: 0.1387726	total: 3m 40s	remaining: 2m 26s
# 700:	learn: 0.1254559	total: 4m 16s	remaining: 1m 49s
# 800:	learn: 0.1144349	total: 4m 54s	remaining: 1m 13s
# 900:	learn: 0.1042251	total: 5m 31s	remaining: 36.4s
# 999:	learn: 0.0955129	total: 6m 7s	remaining: 0us

# %%
features_exp = np.load("features_exp.npy")
pred = clf.predict(features_exp)

fig, ax = plt.subplots(figsize=(1.5,1))
ax.hist(pred.flatten())
# Out:
# (array([2.999e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([5. , 5.2, 5.4, 5.6, 5.8, 6. , 6.2, 6.4, 6.6, 6.8, 7. ]),
#  <BarContainer object of 10 artists>)
