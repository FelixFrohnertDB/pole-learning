# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import accuracy_score
from utils import utils_ml 

from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.feature_selection import VarianceThreshold
from utils import utils_ml
import glob

from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.base import clone
from sklearn.multioutput import ClassifierChain
import numpy as np
import joblib
import os
from catboost import CatBoostClassifier

# %%
# Automatically find the matching file
input_files = glob.glob('training_features*.npy')
if not input_files:
    raise FileNotFoundError("No features_filtered*.npy file found in current directory")
input_path = input_files[0]

# Load memory-mapped array
print(f"Loading features from {input_path}")
X_arr = np.load(input_path, mmap_mode='r').astype(np.float32)[::50]

# Class mapping dictionary
class_to_poles = {
    0: [0, 0, 0],  # 1 pole on [bt]
    1: [1, 0, 0],  # 1 pole on [bb]
    2: [0, 1, 0],  # 1 pole on [tb]
    3: [0, 0, 1],  # 1 pole on [bt] and 1 pole on [bb]
    4: [2, 0, 0],  # 1 pole on [bb] and 1 pole on [tb]
    5: [0, 2, 0],  # 1 pole on each of [bt], [bb], and [tb]
    6: [0, 0, 2],  # 2 poles on [bb] and 1 pole on [tb]
    7: [1, 1, 0],  # 1 pole on [bb] and 2 poles on [tb]
    8: [1, 0, 1],
    9: [0, 1, 1],
    10: [3, 0, 0],
    11: [0, 3, 0],
    12: [0, 0, 3],
    13: [2, 1, 0],
    14: [2, 0, 1],
    15: [1, 2, 0],
    16: [0, 2, 1],
    17: [1, 0, 2],
    18: [0, 1, 2],
    19: [1, 1, 1],
    20: [4, 0, 0],
    21: [0, 4, 0],
    22: [0, 0, 4],
    23: [3, 1, 0],
    24: [3, 0, 1],
    25: [1, 3, 0],
    26: [0, 3, 1],
    27: [1, 0, 3],
    28: [0, 1, 3],
    29: [2, 2, 0],
    30: [2, 0, 2],
    31: [0, 2, 2],
    32: [2, 1, 1],
    33: [1, 2, 1],
    34: [1, 1, 2],
}


# File paths
file_prefix = "rawFeatures/P"
file_suffix = "_intensity.pkl"
num_files = 35

# Load labels
print("Loading labels...")
y_arr_classification = np.array([
    np.tile(i, 10000) 
    for i in np.arange(num_files)
]).flatten()[::50]

def convert_labels(old_labels, class_to_poles):
    """
    Convert class labels to pole representation.
    
    Parameters:
        old_labels (np.ndarray): Array of class labels.
        class_to_poles (dict): Mapping from class labels to pole representations.
        
    Returns:
        np.ndarray: A 2D array with pole representations.
    """
    # Initialize a new array with shape (length of old labels, 3)
    new_labels = np.zeros((len(old_labels), 3), dtype=int)
    
    # Populate the new label array based on the mapping
    for i, label in enumerate(old_labels):
        new_labels[i] = class_to_poles[label]
    
    return new_labels

y_arr_regression = convert_labels(y_arr_classification, class_to_poles) * 1.0

class_to_poles_arr = np.array([class_to_poles[i] for i in range(num_files)])
y_bt = class_to_poles_arr[y_arr_classification][:, 0]
y_bb = class_to_poles_arr[y_arr_classification][:, 1]
y_tb = class_to_poles_arr[y_arr_classification][:, 2]
# Out:
# Loading features from training_features_128_T11T12NoBg.npy
# Loading labels...

# %%
class Ensemble(object):
    
    def __init__(self, esize=10, iterations=1000, seed=42):
        
        
        self.seed = seed
        self.esize=esize
        self.iterations=iterations
        self.ensemble = []
        for e in range(self.esize):
            model = CatBoostClassifier(iterations=self.iterations,
                           loss_function='MultiClass',
                           verbose=100,
                           bootstrap_type='No',
                           posterior_sampling=True,
                           random_seed=self.seed+e,
                           early_stopping_rounds=10)
            self.ensemble.append(model)
        
    def fit(self, X,y, eval_set = None):
        
        for m in self.ensemble:
            m.fit(X, y, use_best_model=True, early_stopping_rounds=10, eval_set=eval_set)
            print("best iter ", m.get_best_iteration())
            print("best score ", m.get_best_score())
            
    
    def predict(self,x):
        probs = []
        
        for m in self.ensemble:
            prob = m.predict_proba(x)
            probs.append(prob)
        probs = np.stack(probs)
        return probs
    
    def save(self, base_filepath):
        """Save the entire ensemble."""
        # Save ensemble metadata
        metadata = {
            'seed': self.seed,
            'esize': self.esize,
            'iterations': self.iterations,
        }
        joblib.dump(metadata, f"{base_filepath}_metadata.pkl")
        
        # Save each model in the ensemble
        os.makedirs(f"{base_filepath}_models", exist_ok=True)
        for idx, model in enumerate(self.ensemble):
            model.save_model(f"{base_filepath}_models/model_{idx}.cbm")
    
    def load(self, base_filepath):
        """Load the entire ensemble."""
        # Load metadata
        metadata = joblib.load(f"{base_filepath}_metadata.pkl")
        self.seed = metadata['seed']
        self.esize = metadata['esize']
        self.iterations = metadata['iterations']
       
        
        # Load each model
        self.ensemble = []
        for idx in range(self.esize):
            model = CatBoostClassifier(
                iterations=self.iterations,
                loss_function='MultiClass',
                verbose=100,
                bootstrap_type='No',
                posterior_sampling=True,
                random_seed=self.seed+idx,
                early_stopping_rounds=10
            )
            model.load_model(f"{base_filepath}_models/model_{idx}.cbm")
            self.ensemble.append(model)


def kl_divergence(probs1, probs2, epsilon=1e-10):
    return np.sum(probs1 * (np.log(probs1 + epsilon) - np.log(probs2 + epsilon)), axis=1)

def entropy_of_expected(probs, epsilon=1e-10):
    mean_probs = np.mean(probs, axis=0)
    log_probs = -np.log(mean_probs + epsilon)
    return np.sum(mean_probs * log_probs, axis=1)

def expected_entropy(probs, epsilon=1e-10):
    log_probs = -np.log(probs + epsilon)

    return np.mean(np.sum(probs * log_probs, axis=2), axis=0)

def mutual_information(probs, epsilon):
    eoe = entropy_of_expected(probs, epsilon)
    exe = expected_entropy(probs, epsilon)
    return eoe - exe

def ensemble_uncertainties(probs, epsilon=1e-10):
    mean_probs = np.mean(probs, axis=0)
    conf = np.max(mean_probs, axis=1)

    eoe = entropy_of_expected(probs, epsilon)
    exe = expected_entropy(probs, epsilon)
    mutual_info = eoe - exe


    uncertainty = {'confidence': conf,
                   'entropy_of_expected': eoe,        # total_uncertainty !
                   'expected_entropy': exe,           # data_uncertainty !
                   'mutual_information': mutual_info, # Knowledge Uncertainty!
                  }

    return uncertainty

class EnsembleWrapper(BaseEstimator, ClassifierMixin):
    def __init__(self, esize=10, iterations=1000, seed=100):
        self.esize = esize
        self.iterations = iterations
        self.seed = seed

        self.ensemble = Ensemble(
            esize=self.esize,
            iterations=self.iterations,
            seed=self.seed
        )

    def fit(self, X, y, eval_set=None):
        if eval_set is not None:
            X_val, y_val = eval_set
            eval_data = [(X_val, y_val)]
        else:
            eval_data = None
        self.ensemble.fit(X, y, eval_set=eval_data)
        self.classes_ = np.unique(y)
        return self

    def predict(self, X):
        probs = self.ensemble.predict(X)
        mean_probs = np.mean(probs, axis=0)
        return np.argmax(mean_probs, axis=1)

    def predict_proba(self, X):
        return np.mean(self.ensemble.predict(X), axis=0)

    def predict_with_uncertainty(self, X):
        probs = self.ensemble.predict(X)
        return ensemble_uncertainties(probs), probs
    
    def save_model(self, filepath):
        """Save the ensemble wrapper model."""
        # Save wrapper metadata
        wrapper_metadata = {
            'esize': self.esize,
            'iterations': self.iterations,
            'seed': self.seed,
            'classes_': getattr(self, 'classes_', None)
        }
        joblib.dump(wrapper_metadata, f"{filepath}_wrapper.pkl")
        
        # Save the ensemble
        self.ensemble.save(filepath)
    
    def load_model(self, filepath):
        """Load the ensemble wrapper model."""
        # Load wrapper metadata
        wrapper_metadata = joblib.load(f"{filepath}_wrapper.pkl")
        self.esize = wrapper_metadata['esize']
        self.iterations = wrapper_metadata['iterations']
        self.seed = wrapper_metadata['seed']
        if wrapper_metadata['classes_'] is not None:
            self.classes_ = wrapper_metadata['classes_']
        
        # Create and load the ensemble
        self.ensemble = Ensemble(
            esize=self.esize,
            iterations=self.iterations,
            seed=self.seed
        )
        self.ensemble.load(filepath)
        return self


class EvalClassifierChain(ClassifierChain):
    def fit(self, X, Y, eval_set=None, **fit_params):
        """Custom fit to support eval_set for each wrapped estimator."""
        X = np.asarray(X)
        Y = np.asarray(Y)

        self.order_ = self.order if self.order != 'random' else np.random.permutation(Y.shape[1])
        self.estimators_ = []

        for chain_idx, label_idx in enumerate(self.order_):
            y = Y[:, label_idx]
            if chain_idx > 0:
                X_extended = np.hstack((X, Y[:, self.order_[:chain_idx]]))
            else:
                X_extended = X

            estimator = clone(self.base_estimator)

            if eval_set is not None:
                X_val, Y_val = eval_set
                y_val = Y_val[:, label_idx]
                if chain_idx > 0:
                    X_val_extended = np.hstack((X_val, Y_val[:, self.order_[:chain_idx]]))
                else:
                    X_val_extended = X_val
                estimator.fit(X_extended, y, eval_set=(X_val_extended, y_val))
            else:
                estimator.fit(X_extended, y)

            self.estimators_.append(estimator)

        return self

    def save_chain(self, base_filepath):
        """Save the entire classifier chain."""
        # Save the chain structure using joblib
        chain_data = {
            'order_': self.order_,
            'order': self.order,
            'base_estimator': self.base_estimator
        }
        joblib.dump(chain_data, f"{base_filepath}_chain.pkl")
        
        # Save each individual estimator
        os.makedirs(f"{base_filepath}_chain_models", exist_ok=True)
        for idx, estimator in enumerate(self.estimators_):
            if hasattr(estimator, 'save_model'):
                estimator.save_model(f"{base_filepath}_chain_models/estimator_{idx}")
            else:
                joblib.dump(estimator, f"{base_filepath}_chain_models/estimator_{idx}.pkl")

    def load_chain(self, base_filepath, classes=None):
        """Load the entire classifier chain."""
        # Load chain structure
        chain_data = joblib.load(f"{base_filepath}_chain.pkl")
        self.order_ = chain_data['order_']
        self.order = chain_data['order']
        self.base_estimator = chain_data['base_estimator']
        
        # Load individual estimators
        self.estimators_ = []
        for idx in range(len(self.order_)):
            estimator = clone(self.base_estimator)
            
            if hasattr(estimator, 'load_model'):
                estimator.load_model(f"{base_filepath}_chain_models/estimator_{idx}")
                # Set classes if provided
                if classes is not None:
                    estimator.classes_ = classes
            else:
                pkl_path = f"{base_filepath}_chain_models/estimator_{idx}.pkl"
                if os.path.exists(pkl_path):
                    estimator = joblib.load(pkl_path)
            
            self.estimators_.append(estimator)
        
        return self

# %%
i = 1
base_model = EnsembleWrapper(esize=5, iterations=1000, seed=42)

unique_classes = np.array([0, 1, 2,])
new_chain = EvalClassifierChain(base_estimator=base_model, order=[0, 1, 2])
new_chain.load_chain(f"models/catboost_model_c3ru_fold{i}", classes=np.unique(y_arr_regression))

# Verify loaded model works
y_pred = new_chain.predict(X_arr)
acc = accuracy_score(utils_ml.reconvert_labels(y_pred,class_to_poles),utils_ml.reconvert_labels(y_arr_regression,class_to_poles))

# %%
# Get pole1 predictions + uncertainty
pole1_uncertainty, pole1_probs = new_chain.estimators_[0].predict_with_uncertainty(X_arr)
pole1_preds = np.argmax(np.mean(pole1_probs, axis=0), axis=1)
X2 = np.concatenate([X_arr, pole1_preds[:, None]], axis=1)

# Get pole2 predictions + uncertainty
pole2_uncertainty, pole2_probs = new_chain.estimators_[1].predict_with_uncertainty(X2)
pole2_preds = np.argmax(np.mean(pole2_probs, axis=0), axis=1)
X3 = np.concatenate([X2, pole2_preds[:, None]], axis=1)

# Get pole3 predictions + uncertainty
pole3_uncertainty, pole3_probs = new_chain.estimators_[2].predict_with_uncertainty(X3)

# %%
predictions = np.stack([np.argmax(np.mean(pole1_probs, axis=0), axis=1),
np.argmax(np.mean(pole2_probs, axis=0), axis=1),
np.argmax(np.mean(pole3_probs, axis=0), axis=1),],axis=1)

predictions_proba = np.stack([np.mean(pole1_probs, axis=0),
np.mean(pole2_probs, axis=0),
np.mean(pole3_probs, axis=0),],axis=1)

# %%
expected_entropy = np.stack([pole1_uncertainty["expected_entropy"],
                             pole2_uncertainty["expected_entropy"],
                             pole3_uncertainty["expected_entropy"]],axis=-1)

mutual_information = np.stack([pole1_uncertainty["mutual_information"],
                             pole2_uncertainty["mutual_information"],
                             pole3_uncertainty["mutual_information"]],axis=-1)

confidence = np.stack([pole1_uncertainty["confidence"],
                             pole2_uncertainty["confidence"],
                             pole3_uncertainty["confidence"]],axis=-1)

# %%
cumulative_entropy = np.cumsum(expected_entropy, axis=1)

# %%
accuracy_score(utils_ml.reconvert_labels(predictions,class_to_poles),utils_ml.reconvert_labels(y_arr_regression,class_to_poles))
# Out:
# 0.8068571428571428

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.rcParams.update({
    'font.size': 5,               # base font size
    'axes.labelsize': 8,
    'xtick.labelsize': 8,
    'ytick.labelsize': 8,
    'legend.fontsize': 8,
    'figure.titlesize': 8
})


def create_plot(c_data):
    # Create a 3×1 grid of plots (one for each position), stacked vertically
    fig, axes = plt.subplots(3, 1, figsize=(3.5, 5.5), sharex=True)
    plt.subplots_adjust(hspace=0.05)  # Small vertical spacing

    positions = ['[bt]', '[bb]', '[tb]']
    n_classes = 5  # Classes 0-4

    cmap_uncertainty = plt.get_cmap("inferno")

    # Compute the max average class entropy across all positions
    max_avg_entropy = 0
    for pos in range(3):
        for cls in range(n_classes):
            mask = y_arr_regression[:, pos] == cls
            if np.any(mask):
                avg_entropy = np.mean(c_data[mask, pos])
                max_avg_entropy = max(max_avg_entropy, avg_entropy)
    max_avg_entropy *=1.5 

    # Find global maximum entropy for consistent color scaling
    global_max_entropy = np.max(c_data) if c_data.size > 0 else 1.5
    global_max_count = 0  # For consistent circle sizing

    # First pass to determine maximum count for sizing
    for pos in range(3):
        for true_cls in range(n_classes):
            for pred_cls in range(n_classes):
                # Count samples where true_cls was predicted as pred_cls
                mask = (y_arr_regression[:, pos] == true_cls) & (predictions[:, pos] == pred_cls)
                count = np.sum(mask)
                global_max_count = max(global_max_count, count)

    for pos in range(3):
        ax = axes[pos]
        
        # Create a confusion matrix filled with uncertainty data
        confusion_counts = np.zeros((n_classes, n_classes), dtype=int)
        mean_uncertainties = np.zeros((n_classes, n_classes))
        
        # Calculate how often each true-predicted class pair occurs and their mean uncertainty
        for true_cls in range(n_classes):
            for pred_cls in range(n_classes):
                # Find samples where true_cls was predicted as pred_cls
                mask = (y_arr_regression[:, pos] == true_cls) & (predictions[:, pos] == pred_cls)
                confusion_counts[true_cls, pred_cls] = np.sum(mask)
                
                # Calculate mean uncertainty for this confusion
                if confusion_counts[true_cls, pred_cls] > 0:
                    mean_uncertainties[true_cls, pred_cls] = np.mean(c_data[mask, pos])
        
        # Calculate accuracy per class
        class_accuracies = np.zeros(n_classes)
        for cls in range(n_classes):
            if np.sum(y_arr_regression[:, pos] == cls) > 0:
                class_accuracies[cls] = confusion_counts[cls, cls] / np.sum(confusion_counts[cls, :])
        
        # Calculate average entropy per class for coloring the accuracy bars
        class_avg_entropies = np.zeros(n_classes)
        for cls in range(n_classes):
            mask = y_arr_regression[:, pos] == cls
            if np.sum(mask) > 0:
                class_avg_entropies[cls] = np.mean(c_data[mask, pos])
        
        # Create confusion matrix heatmap where:
        # - Circle size represents frequency of this confusion
        # - Color intensity represents mean uncertainty
        for true_cls in range(n_classes):
            for pred_cls in range(n_classes):
                if confusion_counts[true_cls, pred_cls] > 0:
                    # Calculate size based on count (normalized by max count)
                    size = 100 * (confusion_counts[true_cls, pred_cls] / global_max_count) ** 0.5
                    size = max(size, 10)  # Minimum size for visibility
                    
                    # Color based on mean uncertainty
                    color_intensity = mean_uncertainties[true_cls, pred_cls] / max_avg_entropy
                    
                    circle = plt.Circle((pred_cls, true_cls), radius=size/150, 
                                    color=cmap_uncertainty(color_intensity),
                                    alpha=1.0,zorder=2)
                    
                    ax.add_patch(circle)
                    
                    # Add text for count (only for significant counts)
                    if confusion_counts[true_cls, pred_cls] > global_max_count * 0.1:
                        ax.text(pred_cls, true_cls, f"{confusion_counts[true_cls, pred_cls]}", 
                                ha='center', va='center', 
                                color='white')# if color_intensity > 0.2 else 'white')
                    
        # Set grid and labels
        ax.set_aspect('equal')
        ax.set_xlim(-0.5, n_classes - 0.5)
        ax.set_ylim(-0.5, n_classes - 0.5)
        ax.set_xticks(range(n_classes))
        ax.set_yticks(range(n_classes))
        ax.set_xticklabels([f'{i}' for i in range(n_classes)])
        ax.set_yticklabels([f'{i}' for i in range(n_classes)])
        ax.grid(True, linestyle='--', alpha=0.7)
        
        # Add class accuracy as a horizontal bar on the right with colors based on entropy
        ax_acc = ax.inset_axes([1.05, 0, 0.15, 1])
        
        # Color bars based on average entropy per class - fixed height of 1
        bar_colors = [cmap_uncertainty(class_avg_entropies[cls] / max_avg_entropy) for cls in range(n_classes)]
        ax_acc.barh(range(n_classes), [1] * n_classes, color=bar_colors)
        
        ax_acc.set_yticks(range(n_classes))
        ax_acc.set_yticklabels([])
        ax_acc.set_xlim(0, 1)


        if pos == 1:
            ax_acc.set_ylabel('Per-Class Accuracy', fontsize=8, rotation=90, labelpad=-35)

        if pos == 2:
            pass
        else:
            ax_acc.set_xticklabels([]) 
            ax_acc.tick_params(axis='x', which='both', length=0)
        
        if pos < 2:
            ax.set_xticklabels([])
            ax.tick_params(axis='x', which='both', length=0)

        # Change accuracy text color to white and center in fixed-width bars
        for i, acc in enumerate(class_accuracies):
            ax_acc.text(0.5, i, f"{acc:.2f}", ha='center', va='center', color='white')
        
        # Calculate statistics
        overall_acc = np.sum(np.diag(confusion_counts)) / np.sum(confusion_counts) if np.sum(confusion_counts) > 0 else 0
        avg_entropy = np.mean(c_data[:, pos])
        
        # Calculate average entropy for correct and incorrect predictions
        correct_mask = predictions[:, pos] == y_arr_regression[:, pos]
        incorrect_mask = ~correct_mask
        entropy_correct = np.mean(c_data[correct_mask, pos]) if np.any(correct_mask) else 0
        entropy_incorrect = np.mean(c_data[incorrect_mask, pos]) if np.any(incorrect_mask) else 0
        
        # Add position label in bottom right
        ax.text(1.0, 0.015, positions[pos], transform=ax.transAxes,
                ha='right', va='bottom', fontsize=8,
                bbox=dict(facecolor='none', edgecolor='none', alpha=0.7))
        
        # Add statistics text in top left - revert to previous format
        stats_text = f"Accuracy: {overall_acc:.2f}\n" \
                    f"Correct Ent.: {entropy_correct:.2f}\n" \
                    f"Incorrect Ent.: {entropy_incorrect:.2f}"
        
        ax.text(0.036, 0.96, stats_text, transform=ax.transAxes,
                ha='left', va='top',  
                bbox=dict(facecolor='white', alpha=1.0))
        
        # Only add labels on specific subplots
        if pos == 1:  # Middle plot gets y-label
            ax.set_ylabel('True Class')
        
        if pos == 2:  # Bottom plot gets x-label
            ax.set_xlabel('Predicted Class')



    # Position colorbar below all axes
    cbar_ax = fig.add_axes([0.294, 0.02, 0.433, 0.02])  # [left, bottom, width, height]
    # sm = plt.cm.ScalarMappable(cmap=cmap_uncertainty)
    # sm.set_array([])
    from matplotlib import colors

    norm = colors.Normalize(vmin=0, vmax=max_avg_entropy)
    sm = plt.cm.ScalarMappable(cmap=cmap_uncertainty, norm=norm)
    sm.set_array([])

    cbar = plt.colorbar(sm, cax=cbar_ax, orientation='horizontal')
    cbar.set_label('Mean Uncertainty (Entropy)')
    cbar.ax.tick_params(labelsize=8)

    plt.savefig("confusion_uncertainty_analysis.pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.show()

create_plot(cumulative_entropy)

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
correct_bt = predictions[:, 0] == y_arr_regression[:, 0]
correct_bb = predictions[:, 1] == y_arr_regression[:, 1]
correct_tb = predictions[:, 2] == y_arr_regression[:, 2]

# Incorrect tb predictions only
tb_incorrect = ~correct_tb

# tb incorrect, but bb and bt were correct → model-specific failure
direct_tb_failures = tb_incorrect & correct_bt & correct_bb

# tb incorrect, and earlier errors exist
cascaded_tb_failures = tb_incorrect & ~(correct_bt & correct_bb)

mean_entropy_direct = np.mean(expected_entropy[direct_tb_failures, 2])
mean_entropy_cascaded = np.mean(expected_entropy[cascaded_tb_failures, 2])

print(f"TB errors from direct failures: {mean_entropy_direct:.2f}")
print(f"TB errors likely caused by cascaded errors: {mean_entropy_cascaded:.2f}")
# Out:
# TB errors from direct failures: 0.63
# TB errors likely caused by cascaded errors: 0.34

# %%
direct_tb_failures.sum(), cascaded_tb_failures.sum()
# Out:
# (1718, 3236)

# %%
# Get all samples where the true label of [tb] is 4
true_tb_4 = y_arr_regression[:, 2] == 4

# But the prediction was wrong
pred_wrong_tb = predictions[:, 2] != 4

# And the model was overconfident (you can set a custom threshold, e.g., entropy < 0.5)
overconfident = expected_entropy[:, 2] < 0.5

# Combined mask: true label is 4, prediction is wrong, model is confident
mask = true_tb_4 & pred_wrong_tb & overconfident

# For these samples, extract relevant info
for i in np.where(mask)[0]:
    print(f"Sample {i}:")
    print(f"  True [bt], [bb], [tb]: {y_arr_regression[i]}")
    print(f"  Pred [bt], [bb], [tb]: {predictions[i]}")
    print(f"  Entropies [bt], [bb], [tb]: {expected_entropy[i]}")
    print(f"  Confidence [bt], [bb], [tb]: {confidence[i]}")
    
    bt_correct = predictions[i, 0] == y_arr_regression[i, 0]
    bb_correct = predictions[i, 1] == y_arr_regression[i, 1]
    
    if not bt_correct or not bb_correct:
        print("  ❗ Error(s) in earlier stages may have propagated.")
    else:
        print("  ✅ Earlier stages correct — final model likely at fault.")
    print("-" * 50)
# Out:
# Sample 22002:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.72213412 0.02502538 0.00649354]
#   Confidence [bt], [bb], [tb]: [0.50213496 0.99650853 0.99919739]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22008:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69582295 0.01258738 0.00562097]
#   Confidence [bt], [bb], [tb]: [0.52201213 0.9983469  0.99932038]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22010:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.695432   0.02047741 0.01400173]
#   Confidence [bt], [bb], [tb]: [0.50990525 0.99709085 0.99806858]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22013:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71872382 0.08518403 0.02152681]
#   Confidence [bt], [bb], [tb]: [0.57276129 0.98334791 0.99684678]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22016:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70649993 0.02452712 0.0091282 ]
#   Confidence [bt], [bb], [tb]: [0.57139262 0.99666321 0.99881941]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22021:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.808675   0.12467308 0.00430652]
#   Confidence [bt], [bb], [tb]: [0.55892175 0.97489054 0.99949301]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22022:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69475913 0.01711207 0.00921959]
#   Confidence [bt], [bb], [tb]: [0.50111117 0.99774243 0.99881435]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22023:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68900801 0.01702942 0.03454276]
#   Confidence [bt], [bb], [tb]: [0.53265281 0.99758936 0.9943737 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22027:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.67758338 0.025571   0.02123451]
#   Confidence [bt], [bb], [tb]: [0.64902673 0.99640742 0.9968593 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22028:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71750846 0.02259123 0.01115729]
#   Confidence [bt], [bb], [tb]: [0.54143943 0.99666553 0.99851207]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22029:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70649835 0.03262823 0.01642866]
#   Confidence [bt], [bb], [tb]: [0.50072416 0.99520694 0.9976559 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22030:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71720657 0.03662784 0.01530446]
#   Confidence [bt], [bb], [tb]: [0.5107088  0.99463727 0.99786818]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22031:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69516328 0.01450326 0.01102869]
#   Confidence [bt], [bb], [tb]: [0.52184867 0.99808046 0.99854202]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22033:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69420682 0.0536007  0.0250585 ]
#   Confidence [bt], [bb], [tb]: [0.52773412 0.99153162 0.99618065]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22036:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71814474 0.06309844 0.02097621]
#   Confidence [bt], [bb], [tb]: [0.53333189 0.98884206 0.99689124]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22038:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.59449476 0.02038735 0.00679963]
#   Confidence [bt], [bb], [tb]: [0.7209851  0.99704956 0.99915504]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22041:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69743016 0.02457803 0.01645132]
#   Confidence [bt], [bb], [tb]: [0.55807119 0.99653705 0.99768216]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22049:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 0 3]
#   Entropies [bt], [bb], [tb]: [0.31313099 0.11893755 0.4040059 ]
#   Confidence [bt], [bb], [tb]: [0.91193512 0.97412605 0.88226065]
#   ✅ Earlier stages correct — final model likely at fault.
# --------------------------------------------------
# Sample 22052:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.7158546  0.03047926 0.01210161]
#   Confidence [bt], [bb], [tb]: [0.52937492 0.9953279  0.99836896]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22054:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68468084 0.02590648 0.01137879]
#   Confidence [bt], [bb], [tb]: [0.60111099 0.9963319  0.99852948]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22055:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69699804 0.01416441 0.01265222]
#   Confidence [bt], [bb], [tb]: [0.52637306 0.99816841 0.99827726]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22056:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.72892889 0.00928446 0.0143573 ]
#   Confidence [bt], [bb], [tb]: [0.55593081 0.99889372 0.99801284]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22060:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69334009 0.03292112 0.00442045]
#   Confidence [bt], [bb], [tb]: [0.56165298 0.99471325 0.99948371]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22063:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69838382 0.03354002 0.02566801]
#   Confidence [bt], [bb], [tb]: [0.55292172 0.99470982 0.9960481 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22067:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69693455 0.02285218 0.04209992]
#   Confidence [bt], [bb], [tb]: [0.50896968 0.99661169 0.99288142]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22068:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68481979 0.04147013 0.01369712]
#   Confidence [bt], [bb], [tb]: [0.57395031 0.99337075 0.99813776]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22070:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 1 3]
#   Entropies [bt], [bb], [tb]: [0.2345563  0.49525154 0.04226995]
#   Confidence [bt], [bb], [tb]: [0.9438569  0.81063646 0.99304038]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22072:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70109311 0.01713697 0.05012849]
#   Confidence [bt], [bb], [tb]: [0.53907331 0.99761388 0.99117015]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22076:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.73804792 0.02095108 0.01431549]
#   Confidence [bt], [bb], [tb]: [0.58658792 0.99710552 0.99801333]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22081:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68945722 0.01926825 0.01261528]
#   Confidence [bt], [bb], [tb]: [0.56420002 0.99744784 0.9982956 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22082:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70575829 0.02224817 0.00295662]
#   Confidence [bt], [bb], [tb]: [0.51168566 0.99681159 0.99967768]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22090:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71440797 0.01372697 0.01347633]
#   Confidence [bt], [bb], [tb]: [0.59326118 0.99816899 0.99814299]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22091:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68339984 0.01186408 0.01208622]
#   Confidence [bt], [bb], [tb]: [0.58233115 0.99852979 0.99835052]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22093:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68865602 0.02418072 0.01076755]
#   Confidence [bt], [bb], [tb]: [0.62785302 0.9966792  0.99858074]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22095:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69454859 0.02684385 0.01304804]
#   Confidence [bt], [bb], [tb]: [0.52654417 0.99588136 0.99821365]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22097:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69036674 0.00729592 0.01105778]
#   Confidence [bt], [bb], [tb]: [0.59515103 0.99914804 0.99852792]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22098:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.700652   0.03014266 0.01435316]
#   Confidence [bt], [bb], [tb]: [0.53833949 0.99563733 0.99800996]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22102:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71977018 0.0350286  0.02835133]
#   Confidence [bt], [bb], [tb]: [0.5097489  0.99456304 0.99563591]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22103:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70686943 0.05412171 0.01419886]
#   Confidence [bt], [bb], [tb]: [0.53926368 0.99097427 0.99805094]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22104:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 1 3]
#   Entropies [bt], [bb], [tb]: [0.29877438 0.51029241 0.04804864]
#   Confidence [bt], [bb], [tb]: [0.93144963 0.82021394 0.99184767]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22109:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 0 3]
#   Entropies [bt], [bb], [tb]: [0.17796306 0.13633112 0.46667441]
#   Confidence [bt], [bb], [tb]: [0.96410712 0.96878174 0.87443985]
#   ✅ Earlier stages correct — final model likely at fault.
# --------------------------------------------------
# Sample 22110:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.77173727 0.08177882 0.00597638]
#   Confidence [bt], [bb], [tb]: [0.54257341 0.98550509 0.99928004]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22112:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.74794842 0.01613062 0.01434541]
#   Confidence [bt], [bb], [tb]: [0.5027376  0.99794396 0.99803593]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22115:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.92356758 0.03070027 0.02576088]
#   Confidence [bt], [bb], [tb]: [0.54935877 0.99563918 0.99610324]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22117:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70694095 0.02251356 0.01287967]
#   Confidence [bt], [bb], [tb]: [0.54760033 0.9967981  0.9982504 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22120:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68873133 0.01248669 0.00918968]
#   Confidence [bt], [bb], [tb]: [0.54514728 0.99842707 0.9988173 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22121:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70808885 0.02158564 0.01054423]
#   Confidence [bt], [bb], [tb]: [0.62552074 0.99698404 0.99861067]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22123:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69159794 0.01835346 0.01712829]
#   Confidence [bt], [bb], [tb]: [0.58816292 0.99758776 0.99760188]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22125:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.73067821 0.02247547 0.01393309]
#   Confidence [bt], [bb], [tb]: [0.52673701 0.9968522  0.99809351]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22130:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.66558118 0.00727406 0.01209142]
#   Confidence [bt], [bb], [tb]: [0.63874598 0.99911303 0.99834712]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22132:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.6791457  0.05258759 0.01303639]
#   Confidence [bt], [bb], [tb]: [0.64806616 0.99099461 0.998204  ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22136:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.67697917 0.01137732 0.01088306]
#   Confidence [bt], [bb], [tb]: [0.6163575  0.99852515 0.99855196]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22139:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [1.04250582 0.07936966 0.02134175]
#   Confidence [bt], [bb], [tb]: [0.43978679 0.98661195 0.99683682]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22141:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.75333142 0.02387982 0.00809909]
#   Confidence [bt], [bb], [tb]: [0.49754817 0.99657582 0.99897385]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22142:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.72792398 0.14866281 0.01689614]
#   Confidence [bt], [bb], [tb]: [0.56012751 0.96707275 0.99759443]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22145:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68239698 0.01076117 0.01848843]
#   Confidence [bt], [bb], [tb]: [0.57605604 0.99869549 0.99732953]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22146:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68742838 0.01254377 0.00866556]
#   Confidence [bt], [bb], [tb]: [0.58196678 0.99840292 0.99889766]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22149:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.67654129 0.01602639 0.01485669]
#   Confidence [bt], [bb], [tb]: [0.61118584 0.99787156 0.99793517]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22153:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.95009642 0.60736293 0.00609603]
#   Confidence [bt], [bb], [tb]: [0.49908176 0.70441793 0.99925604]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22156:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69516109 0.01579131 0.02518666]
#   Confidence [bt], [bb], [tb]: [0.52288731 0.99784118 0.99611373]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22170:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.66498618 0.03030976 0.01265575]
#   Confidence [bt], [bb], [tb]: [0.59651327 0.99555346 0.9982764 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22175:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.66986867 0.01496979 0.00565792]
#   Confidence [bt], [bb], [tb]: [0.60197349 0.99811841 0.99931592]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22180:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 1 3]
#   Entropies [bt], [bb], [tb]: [0.09377728 0.56702567 0.37763894]
#   Confidence [bt], [bb], [tb]: [0.98385063 0.80096624 0.87766058]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22190:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69683183 0.01166047 0.02702185]
#   Confidence [bt], [bb], [tb]: [0.53861493 0.99845864 0.9957881 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22193:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71256804 0.04878918 0.03901357]
#   Confidence [bt], [bb], [tb]: [0.52115482 0.99161579 0.99349902]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22200:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69891798 0.0099088  0.01339876]
#   Confidence [bt], [bb], [tb]: [0.58970013 0.99880646 0.9981713 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22209:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 1 3]
#   Entropies [bt], [bb], [tb]: [0.05436795 0.46955338 0.09644286]
#   Confidence [bt], [bb], [tb]: [0.9915902  0.83224105 0.98030101]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22210:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69950626 0.02697073 0.01347467]
#   Confidence [bt], [bb], [tb]: [0.52475722 0.99617895 0.9981654 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22213:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69491722 0.03290744 0.01338537]
#   Confidence [bt], [bb], [tb]: [0.5075627  0.99504757 0.99817373]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22227:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 1 3]
#   Entropies [bt], [bb], [tb]: [0.58697193 0.68627545 0.02815621]
#   Confidence [bt], [bb], [tb]: [0.73642037 0.54743857 0.99601982]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22246:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.75185805 0.02747445 0.01359961]
#   Confidence [bt], [bb], [tb]: [0.502805   0.99612847 0.99811015]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22247:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68983688 0.03116171 0.00357866]
#   Confidence [bt], [bb], [tb]: [0.58634979 0.99516127 0.9995974 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22248:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.74053842 0.01972908 0.01838228]
#   Confidence [bt], [bb], [tb]: [0.57809652 0.99735788 0.99732838]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22250:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68134221 0.0382638  0.00751899]
#   Confidence [bt], [bb], [tb]: [0.61679768 0.99363011 0.99906399]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22251:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.77484276 0.25630594 0.03712613]
#   Confidence [bt], [bb], [tb]: [0.51058124 0.92928272 0.99392562]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22256:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68598631 0.03300687 0.00938504]
#   Confidence [bt], [bb], [tb]: [0.58775968 0.99470095 0.99878106]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22257:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.7006511  0.01669018 0.01435491]
#   Confidence [bt], [bb], [tb]: [0.51433892 0.99783974 0.99801793]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22260:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.83357088 0.06485708 0.00743312]
#   Confidence [bt], [bb], [tb]: [0.5281068  0.98945412 0.99907993]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22266:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69284215 0.00823324 0.01174554]
#   Confidence [bt], [bb], [tb]: [0.52155425 0.99903485 0.99841942]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22269:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70606997 0.04107644 0.01024322]
#   Confidence [bt], [bb], [tb]: [0.50012478 0.99354615 0.99866931]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22271:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.7538296  0.0607863  0.00707658]
#   Confidence [bt], [bb], [tb]: [0.5846147  0.99021269 0.99912512]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22280:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.73084368 0.04836311 0.00819895]
#   Confidence [bt], [bb], [tb]: [0.63150769 0.9917311  0.99894172]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22281:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68170901 0.01660908 0.01767933]
#   Confidence [bt], [bb], [tb]: [0.5858226  0.99775623 0.99745354]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22282:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.85422159 0.11852857 0.02107064]
#   Confidence [bt], [bb], [tb]: [0.58566303 0.97787106 0.99686776]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22283:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69587791 0.03019275 0.01121563]
#   Confidence [bt], [bb], [tb]: [0.5313322  0.99534389 0.99850305]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22284:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 1 3]
#   Entropies [bt], [bb], [tb]: [0.25184825 0.6937721  0.02477971]
#   Confidence [bt], [bb], [tb]: [0.94244236 0.53910405 0.99634703]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22291:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70014217 0.03371448 0.03072576]
#   Confidence [bt], [bb], [tb]: [0.56174441 0.99464479 0.99513288]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22292:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.66053318 0.01503594 0.00869967]
#   Confidence [bt], [bb], [tb]: [0.62762392 0.99808801 0.99888592]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22293:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.67507421 0.01465303 0.01808522]
#   Confidence [bt], [bb], [tb]: [0.59170335 0.99811067 0.99738348]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22309:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 1 3]
#   Entropies [bt], [bb], [tb]: [0.32843614 0.60947949 0.01447064]
#   Confidence [bt], [bb], [tb]: [0.90581581 0.71282598 0.99814378]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22310:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.72373146 0.02996356 0.01864085]
#   Confidence [bt], [bb], [tb]: [0.65028244 0.99560091 0.99729051]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22312:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68182803 0.00822037 0.00981467]
#   Confidence [bt], [bb], [tb]: [0.59987105 0.99901618 0.99871807]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22317:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.67770721 0.01139865 0.02215654]
#   Confidence [bt], [bb], [tb]: [0.52420648 0.99858147 0.99669959]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22327:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.6670213  0.01062741 0.01448404]
#   Confidence [bt], [bb], [tb]: [0.61622684 0.99866322 0.9979938 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22328:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.67918457 0.01133715 0.00857569]
#   Confidence [bt], [bb], [tb]: [0.56377604 0.99860412 0.99890245]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22330:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.67972177 0.0098973  0.00902689]
#   Confidence [bt], [bb], [tb]: [0.56816088 0.9987869  0.99883647]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22331:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70923901 0.01828408 0.01070165]
#   Confidence [bt], [bb], [tb]: [0.56736866 0.9976183  0.99858373]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22332:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69256356 0.03307449 0.01085437]
#   Confidence [bt], [bb], [tb]: [0.53412521 0.99474741 0.99855158]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22336:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 0 3]
#   Entropies [bt], [bb], [tb]: [0.66133897 0.00766982 0.42264132]
#   Confidence [bt], [bb], [tb]: [0.61082674 0.99903269 0.85143829]
#   ✅ Earlier stages correct — final model likely at fault.
# --------------------------------------------------
# Sample 22337:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.72721614 0.00951717 0.04405878]
#   Confidence [bt], [bb], [tb]: [0.53504843 0.99880936 0.99245955]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22340:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.74524706 0.02534234 0.01932463]
#   Confidence [bt], [bb], [tb]: [0.54302543 0.9965104  0.9971797 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22341:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69626498 0.0218192  0.01415691]
#   Confidence [bt], [bb], [tb]: [0.51310609 0.99685088 0.99804998]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22348:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68604955 0.00993789 0.01584725]
#   Confidence [bt], [bb], [tb]: [0.58092028 0.9988066  0.99776322]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22349:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70884886 0.01409351 0.00821734]
#   Confidence [bt], [bb], [tb]: [0.50358007 0.99820811 0.99896519]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22353:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70504224 0.0564018  0.01984601]
#   Confidence [bt], [bb], [tb]: [0.60578949 0.99062774 0.99716275]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22357:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.6990496  0.01413085 0.00657985]
#   Confidence [bt], [bb], [tb]: [0.50066537 0.99807203 0.99918873]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22368:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69905523 0.01121203 0.02039145]
#   Confidence [bt], [bb], [tb]: [0.53613648 0.99863267 0.99698549]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22375:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69938145 0.02188624 0.01922503]
#   Confidence [bt], [bb], [tb]: [0.52979523 0.99686632 0.99721552]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22378:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.73687002 0.02226258 0.01467251]
#   Confidence [bt], [bb], [tb]: [0.52255184 0.99687815 0.99795952]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22380:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69056579 0.01108094 0.00529315]
#   Confidence [bt], [bb], [tb]: [0.59252136 0.99862508 0.9993642 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22388:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68795726 0.04556437 0.02541466]
#   Confidence [bt], [bb], [tb]: [0.61102472 0.99209226 0.996091  ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22390:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.80551983 0.06605378 0.05374138]
#   Confidence [bt], [bb], [tb]: [0.50992229 0.98804877 0.99034279]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22394:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.74173512 0.03968309 0.02372623]
#   Confidence [bt], [bb], [tb]: [0.50059852 0.99369326 0.99643143]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22396:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70598127 0.01380008 0.00689165]
#   Confidence [bt], [bb], [tb]: [0.54190491 0.99818267 0.99913334]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22399:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.9235055  0.17189916 0.00871196]
#   Confidence [bt], [bb], [tb]: [0.46446331 0.96477854 0.99887018]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22402:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70496118 0.13213739 0.00461767]
#   Confidence [bt], [bb], [tb]: [0.63206393 0.97080021 0.99945497]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22403:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.75815887 0.02444273 0.02191103]
#   Confidence [bt], [bb], [tb]: [0.6373015  0.99652749 0.99673257]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22406:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68193729 0.01749877 0.02171394]
#   Confidence [bt], [bb], [tb]: [0.50326278 0.99752668 0.99677227]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22408:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68021093 0.01406618 0.02348164]
#   Confidence [bt], [bb], [tb]: [0.66850424 0.9981349  0.99646742]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22416:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.74193188 0.14917466 0.00449634]
#   Confidence [bt], [bb], [tb]: [0.60199584 0.96581317 0.99947391]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22418:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.72820736 0.02200823 0.01183806]
#   Confidence [bt], [bb], [tb]: [0.5185571  0.9970261  0.99840353]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22430:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71010618 0.01962987 0.00858351]
#   Confidence [bt], [bb], [tb]: [0.53492176 0.99740573 0.99891866]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22431:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68902331 0.04373383 0.01957187]
#   Confidence [bt], [bb], [tb]: [0.60207945 0.99270398 0.99711622]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22434:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 1 3]
#   Entropies [bt], [bb], [tb]: [0.36586572 0.62599193 0.05823524]
#   Confidence [bt], [bb], [tb]: [0.90603238 0.74897871 0.98999179]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22435:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70355828 0.03511191 0.02590301]
#   Confidence [bt], [bb], [tb]: [0.52529418 0.99427337 0.99600979]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22437:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70905713 0.01247007 0.00792336]
#   Confidence [bt], [bb], [tb]: [0.51551508 0.99844414 0.99900008]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22447:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69079074 0.01257676 0.01432645]
#   Confidence [bt], [bb], [tb]: [0.54990248 0.99843606 0.99802102]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22451:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.72581577 0.06111428 0.00964858]
#   Confidence [bt], [bb], [tb]: [0.49828509 0.98879989 0.99873473]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22452:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.64171221 0.01668603 0.00842127]
#   Confidence [bt], [bb], [tb]: [0.66027067 0.99779845 0.9989186 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22455:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69454841 0.05808754 0.00504853]
#   Confidence [bt], [bb], [tb]: [0.60245959 0.98964048 0.99940391]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22460:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69245403 0.03065841 0.00873411]
#   Confidence [bt], [bb], [tb]: [0.58727971 0.99519253 0.99886395]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22465:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68837881 0.01340207 0.01319504]
#   Confidence [bt], [bb], [tb]: [0.51119251 0.99818235 0.99821597]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22467:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68846565 0.02652495 0.01839759]
#   Confidence [bt], [bb], [tb]: [0.51595499 0.9959964  0.99732491]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22468:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.73715775 0.07586525 0.03071756]
#   Confidence [bt], [bb], [tb]: [0.51293294 0.98670199 0.99468514]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22476:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71150482 0.05635382 0.00457112]
#   Confidence [bt], [bb], [tb]: [0.57737123 0.99009358 0.99946933]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22481:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.6964302  0.03281435 0.00873517]
#   Confidence [bt], [bb], [tb]: [0.59937506 0.99518806 0.99888968]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22487:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.67665495 0.03137594 0.01060145]
#   Confidence [bt], [bb], [tb]: [0.60196061 0.99554499 0.99860744]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22490:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70652681 0.01780452 0.019231  ]
#   Confidence [bt], [bb], [tb]: [0.59258586 0.99768789 0.99721749]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22502:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69864074 0.01959226 0.00879512]
#   Confidence [bt], [bb], [tb]: [0.53506938 0.9973735  0.99887415]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22506:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69551212 0.01356774 0.01160954]
#   Confidence [bt], [bb], [tb]: [0.54767966 0.99831304 0.99843838]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22507:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68933032 0.01326014 0.02174069]
#   Confidence [bt], [bb], [tb]: [0.60243508 0.99831211 0.99676127]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22508:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.65269976 0.070763   0.04206463]
#   Confidence [bt], [bb], [tb]: [0.66078501 0.98644328 0.99287014]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22515:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.72267259 0.03170455 0.02537095]
#   Confidence [bt], [bb], [tb]: [0.57988056 0.99522747 0.99609497]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22517:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69707207 0.01774323 0.00521852]
#   Confidence [bt], [bb], [tb]: [0.5033835  0.99769362 0.9993795 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22518:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.6899812  0.01623403 0.00932698]
#   Confidence [bt], [bb], [tb]: [0.50499222 0.99782583 0.99880046]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22520:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68049931 0.02440013 0.01168599]
#   Confidence [bt], [bb], [tb]: [0.60945418 0.99637764 0.99843137]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22527:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68753905 0.01330452 0.0118276 ]
#   Confidence [bt], [bb], [tb]: [0.58073271 0.99829017 0.99840653]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22529:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.7880356  0.08442658 0.02735719]
#   Confidence [bt], [bb], [tb]: [0.50917769 0.984259   0.99575011]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22531:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69145248 0.0089053  0.00684131]
#   Confidence [bt], [bb], [tb]: [0.55798399 0.99894884 0.99915344]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22532:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.7010952  0.00997376 0.03041374]
#   Confidence [bt], [bb], [tb]: [0.54735605 0.99874791 0.99518061]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22536:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [1 0 3]
#   Entropies [bt], [bb], [tb]: [0.67863032 0.3401244  0.07712441]
#   Confidence [bt], [bb], [tb]: [0.79312689 0.89539995 0.98667922]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22537:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
# ...
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22864:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70889616 0.0786825  0.01817473]
#   Confidence [bt], [bb], [tb]: [0.57186106 0.98562964 0.99740258]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22866:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.7507268  0.03136425 0.02338061]
#   Confidence [bt], [bb], [tb]: [0.59467025 0.99556278 0.99648076]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22867:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69316099 0.00710217 0.02586703]
#   Confidence [bt], [bb], [tb]: [0.58066698 0.99915273 0.99597592]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22869:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.88405428 0.1306007  0.00726211]
#   Confidence [bt], [bb], [tb]: [0.47148696 0.97310538 0.99910247]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22870:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.73099981 0.00946168 0.01094082]
#   Confidence [bt], [bb], [tb]: [0.60643127 0.99886848 0.99855095]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22871:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.76689641 0.02976974 0.02212624]
#   Confidence [bt], [bb], [tb]: [0.52497685 0.99583872 0.99665454]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22872:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70201261 0.01713742 0.00812925]
#   Confidence [bt], [bb], [tb]: [0.60042009 0.9977599  0.99897748]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22876:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.6903085  0.01331299 0.01901805]
#   Confidence [bt], [bb], [tb]: [0.59516789 0.99824101 0.99717862]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22878:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.56573225 0.01607111 0.02112408]
#   Confidence [bt], [bb], [tb]: [0.75270367 0.99792463 0.9968856 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22881:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68905746 0.00975632 0.00966092]
#   Confidence [bt], [bb], [tb]: [0.50481955 0.99882075 0.9987511 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22882:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.73354221 0.03438239 0.03580737]
#   Confidence [bt], [bb], [tb]: [0.58295276 0.99459904 0.9939697 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22885:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69575849 0.01885401 0.00414598]
#   Confidence [bt], [bb], [tb]: [0.59021484 0.99738435 0.99952429]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22890:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70490274 0.0312848  0.00928239]
#   Confidence [bt], [bb], [tb]: [0.57317652 0.99538649 0.9988209 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22897:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69297183 0.01540238 0.01468839]
#   Confidence [bt], [bb], [tb]: [0.57724154 0.99790999 0.99794858]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22899:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69587784 0.01694047 0.01805101]
#   Confidence [bt], [bb], [tb]: [0.50902445 0.99769772 0.99740496]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22901:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.75656034 0.01357054 0.01867379]
#   Confidence [bt], [bb], [tb]: [0.57683569 0.99819239 0.99728072]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22904:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [1 0 3]
#   Entropies [bt], [bb], [tb]: [1.12632165 0.39740451 0.49951488]
#   Confidence [bt], [bb], [tb]: [0.46133696 0.86119313 0.83620963]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22907:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.76153349 0.05677533 0.00991524]
#   Confidence [bt], [bb], [tb]: [0.52586699 0.99099361 0.99872525]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22911:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71316144 0.05204176 0.01340197]
#   Confidence [bt], [bb], [tb]: [0.55924795 0.99157238 0.99814793]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22918:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.72210154 0.01684854 0.01027308]
#   Confidence [bt], [bb], [tb]: [0.61052158 0.99774053 0.99864183]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22920:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70319622 0.02733284 0.01055295]
#   Confidence [bt], [bb], [tb]: [0.50830648 0.99599176 0.99863459]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22927:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.75479103 0.10424672 0.00775164]
#   Confidence [bt], [bb], [tb]: [0.58106803 0.98143597 0.99904314]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22929:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 1 3]
#   Entropies [bt], [bb], [tb]: [0.36553144 0.62673507 0.0198663 ]
#   Confidence [bt], [bb], [tb]: [0.88808787 0.69669421 0.99724429]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22930:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.74567943 0.02116288 0.01505516]
#   Confidence [bt], [bb], [tb]: [0.50433489 0.99707031 0.99789834]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22935:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.73991706 0.065264   0.00916742]
#   Confidence [bt], [bb], [tb]: [0.57617581 0.98945174 0.99882809]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22937:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70618522 0.01722769 0.02620593]
#   Confidence [bt], [bb], [tb]: [0.60171257 0.9977766  0.99588952]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22939:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [0 0 2]
#   Entropies [bt], [bb], [tb]: [0.16762543 0.16843471 0.31496475]
#   Confidence [bt], [bb], [tb]: [0.96480805 0.95972883 0.92594384]
#   ✅ Earlier stages correct — final model likely at fault.
# --------------------------------------------------
# Sample 22940:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69544562 0.01846763 0.02685542]
#   Confidence [bt], [bb], [tb]: [0.5327089  0.99740383 0.99586339]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22941:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.76732813 0.05708341 0.01761887]
#   Confidence [bt], [bb], [tb]: [0.53306864 0.99022591 0.99746325]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22942:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68828484 0.03412143 0.00845032]
#   Confidence [bt], [bb], [tb]: [0.55902705 0.99456033 0.99892678]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22943:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70693224 0.05312026 0.01979933]
#   Confidence [bt], [bb], [tb]: [0.64948827 0.99162043 0.99715798]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22946:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.66831865 0.01664972 0.02160175]
#   Confidence [bt], [bb], [tb]: [0.62849219 0.99783556 0.99680266]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22948:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.65817293 0.02067798 0.01660964]
#   Confidence [bt], [bb], [tb]: [0.63388362 0.99726861 0.99763477]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22953:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69455949 0.02207547 0.01626449]
#   Confidence [bt], [bb], [tb]: [0.54061068 0.99702883 0.9977407 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22955:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69008881 0.01552092 0.01176079]
#   Confidence [bt], [bb], [tb]: [0.54532032 0.9979792  0.99841135]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22956:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69107081 0.00553794 0.01432723]
#   Confidence [bt], [bb], [tb]: [0.56932804 0.99937695 0.99800671]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22960:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.69438049 0.01851019 0.01117359]
#   Confidence [bt], [bb], [tb]: [0.51388204 0.9974397  0.99850829]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22965:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.68510274 0.05304262 0.0310757 ]
#   Confidence [bt], [bb], [tb]: [0.50423188 0.99060387 0.99508294]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22966:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.82238963 0.02256243 0.03265131]
#   Confidence [bt], [bb], [tb]: [0.4878542  0.9969655  0.99472445]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22970:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [1.04229441 0.1809586  0.00161069]
#   Confidence [bt], [bb], [tb]: [0.43163317 0.95696638 0.99983447]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22975:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.67320926 0.03144574 0.01775869]
#   Confidence [bt], [bb], [tb]: [0.61679115 0.99525573 0.9974275 ]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22976:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.75326717 0.13657714 0.00406373]
#   Confidence [bt], [bb], [tb]: [0.58924332 0.96892888 0.99953317]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22978:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.70109586 0.03788934 0.01010188]
#   Confidence [bt], [bb], [tb]: [0.5816558  0.99443661 0.99868941]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22980:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.84761386 0.01500378 0.02280461]
#   Confidence [bt], [bb], [tb]: [0.49547381 0.99808768 0.99657617]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22985:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71506339 0.22111273 0.06647092]
#   Confidence [bt], [bb], [tb]: [0.52111487 0.94242229 0.98772666]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22991:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.6949879  0.02625983 0.02992123]
#   Confidence [bt], [bb], [tb]: [0.67716596 0.99621032 0.99523113]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22992:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.71432721 0.04152181 0.04043826]
#   Confidence [bt], [bb], [tb]: [0.550036   0.9929436  0.99323308]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22993:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.79816984 0.01061281 0.02570854]
#   Confidence [bt], [bb], [tb]: [0.49817173 0.9986431  0.99605367]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22996:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [0.64514194 0.01098132 0.0044145 ]
#   Confidence [bt], [bb], [tb]: [0.67410182 0.99860139 0.99948171]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------
# Sample 22998:
#   True [bt], [bb], [tb]: [0. 0. 4.]
#   Pred [bt], [bb], [tb]: [3 1 0]
#   Entropies [bt], [bb], [tb]: [8.25739603e-01 2.01502145e-01 7.03210852e-04]
#   Confidence [bt], [bb], [tb]: [0.52185478 0.95166573 0.99993424]
#   ❗ Error(s) in earlier stages may have propagated.
# --------------------------------------------------

# %%
# Gather all entropies and confidences from selected failing samples
entropies_all = []
confidences_all = []

for i in np.where(mask)[0]:
    entropies_all.append(expected_entropy[i])
    confidences_all.append(confidence[i])  # Make sure you have confidence[:, pos] available

entropies_all = np.array(entropies_all)
confidences_all = np.array(confidences_all)

# Compute mean ± std across all three positions
mean_entropy = np.mean(entropies_all, axis=0)
std_entropy = np.std(entropies_all, axis=0)

mean_confidence = np.mean(confidences_all, axis=0)
std_confidence = np.std(confidences_all, axis=0)

# Print in ± notation
for i, label in enumerate(['bt', 'bb', 'tb']):
    print(f"Entropy [{label}]: {mean_entropy[i]:.2f} ± {std_entropy[i]:.2f}")
    print(f"Confidence [{label}]: {mean_confidence[i]:.2f} ± {std_confidence[i]:.2f}")
# Out:
# Entropy [bt]: 0.68 ± 0.15
# Confidence [bt]: 0.59 ± 0.12
# Entropy [bb]: 0.09 ± 0.17
# Confidence [bb]: 0.97 ± 0.09
# Entropy [tb]: 0.03 ± 0.07
# Confidence [tb]: 0.99 ± 0.02
